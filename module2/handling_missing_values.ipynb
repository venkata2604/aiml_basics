# %%
import pandas as pd
import numpy as np

np.random.seed(0)

# %%
nfl_data_file_v3 = r"/mnt/d/aiml_basics/dataset/NFL Play by Play 2009-2016 (v3)/NFL Play by Play 2009-2016 (v3).csv"
nfl_data_file_v4 = r"/mnt/d/aiml_basics/dataset/NFL Play by Play 2009-2017 (v4)/NFL Play by Play 2009-2017 (v4).csv"
sf_permits_file = r"/mnt/d/aiml_basics/dataset/Building_Permits.csv/Building_Permits.csv"

# %%
df_nfl_v3 = pd.read_csv(nfl_data_file_v3)
# Out:
# /tmp/ipykernel_183370/2361341864.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nfl_v3 = pd.read_csv(nfl_data_file_v3)

# %%
df_nfl_v4 = pd.read_csv(nfl_data_file_v4)
# Out:
# /tmp/ipykernel_183370/4110983858.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nfl_v4 = pd.read_csv(nfl_data_file_v4)

# %%
df_building_permits = pd.read_csv(sf_permits_file)
# Out:
# /tmp/ipykernel_183370/2904628278.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_building_permits = pd.read_csv(sf_permits_file)

# %%
df_nfl_v3.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
df_nfl_v4.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
df_nfl_v4.describe()
# Out:
#              GameID          Drive            qtr           down  \
# count  4.076880e+05  407688.000000  407688.000000  346534.000000
# mean   2.013158e+09      12.316158       2.577412       2.002476
# std    2.572839e+06       7.149527       1.129750       1.006353
# min    2.009091e+09       1.000000       1.000000       1.000000
# 25%    2.011101e+09       6.000000       2.000000       1.000000
# 50%    2.013111e+09      12.000000       3.000000       2.000000
# 75%    2.015121e+09      18.000000       4.000000       3.000000
# max    2.017123e+09      35.000000       5.000000       4.000000
#
#            TimeUnder       TimeSecs   PlayTimeDiff          yrdln  \
# count  407688.000000  407464.000000  407244.000000  406848.000000
# mean        7.374200    1695.268944      20.576762      28.488327
# std         4.642388    1062.801012      17.969326      12.946471
# min         0.000000    -900.000000       0.000000       1.000000
# ...

# %%
s = np.random.choice([1,2,3,4,5,6,7], 5, replace=True)
print(s)
# Out:
# [1 1 5 6 6]

# %%
df_nfl_v3.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 17860   2009-10-26  2009102600     23    4   2.0  05:36          6     336.0
# 51505   2010-09-26  2010092604      1    1   1.0  14:55         15    3595.0
# 336754  2016-10-30  2016103007      6    2   2.0  14:15         15    2655.0
# 18278   2009-11-01  2009110102     10    2   4.0  08:48          9    2328.0
# 197016  2013-10-20  2013102008     23    4   1.0  12:09         13     729.0
#
#         PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 17860            0.0         PHI  ... -3.097231     0.072297     0.927703
# 51505            5.0         BAL  ...       NaN     0.514427     0.485573
# 336754          39.0         OAK  ...       NaN     0.816480     0.183520
# 18278           18.0         CLE  ...       NaN     0.776160     0.223840
# 197016          45.0         PHI  ...       NaN     0.133741     0.866259
#
# ...

# %%
df_building_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
# finding missing values in building permits data

df_building_permits.columns.values
# Out:
# array(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Block', 'Lot', 'Street Number',
#        'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
#        'Unit Suffix', 'Description', 'Current Status',
#        'Current Status Date', 'Filed Date', 'Issued Date',
#        'Completed Date', 'First Construction Document Date',
#        'Structural Notification', 'Number of Existing Stories',
#        'Number of Proposed Stories', 'Voluntary Soft-Story Retrofit',
#        'Fire Only Permit', 'Permit Expiration Date', 'Estimated Cost',
#        'Revised Cost', 'Existing Use', 'Existing Units', 'Proposed Use',
#        'Proposed Units', 'Plansets', 'TIDF Compliance',
#        'Existing Construction Type',
#        'Existing Construction Type Description',
#        'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries',
# ...

# %%
pd.isnull(df_building_permits["Proposed Construction Type"].values.any())
# Out:
# False
